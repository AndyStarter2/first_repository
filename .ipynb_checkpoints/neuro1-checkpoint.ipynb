# %%
import mne
import openneuro
from pathlib import Path

# %%
# Указываем параметры для вашего датасета
dataset = "ds005385"
subject = "001"  # или любой другой subject ID из этого датасета

# Создаем путь для скачивания
bids_root = Path("./data") / dataset  # скачаем в папку data/ds005385 текущей директории
bids_root.mkdir(parents=True, exist_ok=True)

print(f"Скачиваем датасет {dataset}, субъект {subject}...")
print(f"Файлы будут сохранены в: {bids_root.absolute()}")

# Скачиваем только данные указанного субъекта
openneuro.download(
    dataset=dataset,
    target_dir=bids_root,
    include=[f"sub-{subject}"]  # скачиваем только одного субъекта
)

print("Скачивание завершено!")
# Out:
# Скачиваем датасет ds005385, субъект 001...
# Файлы будут сохранены в: C:\Users\me\Documents\Projects_Python314\data\ds005385
#
# 👋 Hello! This is openneuro-py 2025.1.0. Great to see you! 🤗
#
#    👉 Please report problems 🤯 and bugs 🪲 at
#       https://github.com/hoechenberger/openneuro-py/issues
#
# 🌍 Preparing to download ds005385 …
# 📁 Traversing directories for ds005385 : 0 entities [00:00, ? entities/s]
# 📥 Retrieving up to 46 files (5 concurrent downloads).
# ✅ Finished downloading ds005385.
#
# 🧠 Please enjoy your brains.
#
# Скачивание завершено!
# 🔄 Request timed out while downloading C:\Users\me\Documents\Projects_Python314\data\ds005385\sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-post_eeg.edf, retrying in 0.5 sec …
# dataset_description.json:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# participants.tsv:   0%|          | 0.00/18.9k [00:00<?, ?B/s]
# sub-001_sessions.tsv:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# participants.json:   0%|          | 0.00/962 [00:00<?, ?B/s]
# CHANGES:   0%|          | 0.00/180 [00:00<?, ?B/s]
# sub-001_sessions.json:   0%|          | 0.00/206 [00:00<?, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-post_eeg.edf:   0%|          | 0.00/23.9M [00:00<?, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-post_channels.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-post_events.json: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-pre_channels.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-post_eeg.json:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-pre_eeg.json: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-post_events.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-pre_events.json: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-pre_eeg.edf:   0%|          | 0.00/22.8M [00:00<?, ?B/s]
# sub-001_ses-1_task-EyesClosed_acq-pre_events.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-post_channels.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-post_events.json: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-post_eeg.json:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-pre_channels.tsv:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-post_events.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-pre_eeg.edf:   0%|          | 0.00/22.8M [00:00<?, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-pre_eeg.json:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-pre_events.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-post_channels.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-pre_events.tsv:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-post_eeg.json: 0.00B [00:00, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-post_events.json: 0.00B [00:00, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-post_eeg.edf:   0%|          | 0.00/22.8M [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-post_events.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-pre_channels.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-pre_eeg.edf:   0%|          | 0.00/22.5M [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-pre_eeg.json:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-pre_events.json: 0.00B [00:00, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-post_channels.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-2_task-EyesClosed_acq-pre_events.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-post_events.json: 0.00B [00:00, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-post_eeg.edf:   0%|          | 0.00/22.8M [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-post_events.tsv: 0.00B [00:00, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-post_eeg.json:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-pre_channels.tsv:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-pre_eeg.edf:   0%|          | 0.00/23.8M [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-pre_eeg.json:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-pre_events.tsv:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# sub-001_ses-2_task-EyesOpen_acq-pre_events.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# sub-001_ses-1_task-EyesOpen_acq-post_eeg.edf:   0%|          | 0.00/23.0M [00:00<?, ?B/s]

# %%
bids_root = Path("./data/ds005385")

# Проверяем структуру скачанных файлов
print("Структура скачанного датасета:")
for path in bids_root.rglob("*"):
    if path.is_file():
        print(f"  {path.relative_to(bids_root)}")
        # Проверяем размер файла
        print(f"    Размер: {path.stat().st_size} байт")

# Проверяем конкретно проблемный файл
problem_file = bids_root / "sub-001/ses-1/eeg/sub-001_ses-1_task-EyesOpen_acq-post_eeg.edf"
if problem_file.exists():
    print(f"✓ Проблемный файл скачан: {problem_file.stat().st_size} байт")
else:
    print(f"✗ Проблемный файл отсутствует: {problem_file}")
# Out:
# Структура скачанного датасета:
#   CHANGES
#     Размер: 180 байт
#   dataset_description.json
#     Размер: 1807 байт
#   participants.json
#     Размер: 962 байт
#   participants.tsv
#     Размер: 19398 байт
#   sub-001\sub-001_sessions.json
#     Размер: 206 байт
#   sub-001\sub-001_sessions.tsv
#     Размер: 48 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-post_channels.tsv
#     Размер: 1228 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-post_eeg.edf
#     Размер: 23936896 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-post_eeg.json
#     Размер: 1087 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-post_events.json
#     Размер: 237 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-post_events.tsv
#     Размер: 35 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-pre_channels.tsv
#     Размер: 1228 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-pre_eeg.edf
#     Размер: 23546896 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-pre_eeg.json
#     Размер: 1087 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-pre_events.json
#     Размер: 237 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesClosed_acq-pre_events.tsv
#     Размер: 35 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-post_channels.tsv
#     Размер: 1228 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-post_eeg.edf
#     Размер: 23936896 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-post_eeg.json
#     Размер: 1087 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-post_events.json
#     Размер: 237 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-post_events.tsv
#     Размер: 35 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-pre_channels.tsv
#     Размер: 1228 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-pre_eeg.edf
#     Размер: 24976896 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-pre_eeg.json
#     Размер: 1087 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-pre_events.json
#     Размер: 237 байт
#   sub-001\ses-2\eeg\sub-001_ses-2_task-EyesOpen_acq-pre_events.tsv
#     Размер: 35 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-post_channels.tsv
#     Размер: 1228 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-post_eeg.edf
#     Размер: 25106896 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-post_eeg.json
#     Размер: 1087 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-post_events.json
#     Размер: 237 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-post_events.tsv
#     Размер: 35 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-pre_channels.tsv
#     Размер: 1228 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-pre_eeg.edf
#     Размер: 23936896 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-pre_eeg.json
#     Размер: 1087 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-pre_events.json
#     Размер: 237 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-pre_events.tsv
#     Размер: 35 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-post_channels.tsv
#     Размер: 1228 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-post_eeg.edf
#     Размер: 24066896 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-post_eeg.json
#     Размер: 1087 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-post_events.json
#     Размер: 237 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-post_events.tsv
#     Размер: 35 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-pre_channels.tsv
#     Размер: 1228 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-pre_eeg.edf
#     Размер: 23936896 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-pre_eeg.json
#     Размер: 1087 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-pre_events.json
#     Размер: 237 байт
#   sub-001\ses-1\eeg\sub-001_ses-1_task-EyesOpen_acq-pre_events.tsv
#     Размер: 35 байт
# ✓ Проблемный файл скачан: 24066896 байт

# %%
from mne_bids import BIDSPath, read_raw_bids

bids_root = "./data/ds005385"

# Создаем BIDSPath с указанием acquisition
bids_path = BIDSPath(
    subject='001',
    session='1',
    task='EyesClosed',
    acquisition='post',  # добавляем параметр acquisition
    datatype='eeg',
    root=bids_root
)

print("Пробуем загрузить данные EyesClosed acq-post...")

try:
    raw = read_raw_bids(bids_path)
    print("✓ Данные успешно загружены!")
    print(raw)
    
    # Проверяем и устанавливаем расположение электродов
    if raw.info['dig'] is None:
        print("Устанавливаем стандартное расположение электродов...")
        raw.set_montage('standard_1020')
    
    # Показываем сырые данные
    print("Открываем просмотр сырых данных...")
    raw.plot()
    
except Exception as e:
    print(f"Ошибка при загрузке: {e}")
# Out:
# Пробуем загрузить данные EyesClosed acq-post...
# Extracting EDF parameters from C:\Users\me\Documents\Projects_Python314\data\ds005385\sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-post_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from data\ds005385\sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-post_events.tsv.
# Reading channel info from data\ds005385\sub-001\ses-1\eeg\sub-001_ses-1_task-EyesClosed_acq-post_channels.tsv.
# ✓ Данные успешно загружены!
# <RawEDF | sub-001_ses-1_task-EyesClosed_acq-post_eeg.edf, 65 x 193000 (193.0 s), ~54 KiB, data not loaded>
# Устанавливаем стандартное расположение электродов...
# Открываем просмотр сырых данных...
# Using matplotlib as 2D backend.
# C:\Users\me\AppData\Local\Temp\ipykernel_3416\777232590.py:18: RuntimeWarning: The number of channels in the channels.tsv sidecar file (64) does not match the number of channels in the raw data file (65). Will not try to set channel names.
#   raw = read_raw_bids(bids_path)
# C:\Users\me\AppData\Local\Temp\ipykernel_3416\777232590.py:18: RuntimeWarning: Unable to map the following column(s) to to MNE:
# handedness: right
# session1: yes
# late_ses1: 0
# session2: yes
# late_ses2: 0
#   raw = read_raw_bids(bids_path)
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
# Проверим основные параметры данных
print("Информация о данных:")
print(f"Количество каналов: {len(raw.ch_names)}")
print(f"Частота дискретизации: {raw.info['sfreq']} Гц")
print(f"Длительность записи: {raw.times[-1]:.2f} секунд")
print(f"Типы каналов: {set(ch['kind'] for ch in raw.info['chs'])}")

# Посмотрим на имена каналов
print("\nПервые 10 каналов:")
for ch_name in raw.ch_names[:10]:
    print(f"  {ch_name}")

# Проверим, есть ли у нас координаты для каналов после установки montage
if raw.info['dig'] is not None:
    print("\n✓ Расположение электродов установлено")
else:
    print("\n✗ Расположение электродов не установлено")
# Out:
# Информация о данных:
# Количество каналов: 65
# Частота дискретизации: 1000.0 Гц
# Длительность записи: 193.00 секунд
# Типы каналов: {2 (FIFFV_EEG_CH), 3 (FIFFV_STIM_CH)}
#
# Первые 10 каналов:
#   Fp1
#   Fp2
#   F7
#   F3
#   Fz
#   F4
#   F8
#   FC5
#   FC1
#   FC2
#
# ✓ Расположение электродов установлено

# %%
# Проверим, какие каналы у нас есть и отберем только EEG
print("Анализ каналов:")
eeg_picks = mne.pick_types(raw.info, eeg=True, eog=False, ecg=False, stim=False)
print(f"EEG каналов: {len(eeg_picks)}")
print(f"Стимульные каналы: {len(raw.info['chs']) - len(eeg_picks)}")

# Посмотрим на имена EEG каналов
eeg_ch_names = [raw.ch_names[i] for i in eeg_picks]
print("EEG каналы:")
for i in range(0, len(eeg_ch_names), 8):
    print("  " + ", ".join(eeg_ch_names[i:i+8]))
# Out:
# Анализ каналов:
# EEG каналов: 64
# Стимульные каналы: 1
# EEG каналы:
#   Fp1, Fp2, F7, F3, Fz, F4, F8, FC5
#   FC1, FC2, FC6, T7, C3, Cz, C4, T8
#   TP9, CP5, CP1, CP2, CP6, TP10, P7, P3
#   Pz, P4, P8, PO9, O1, Oz, O2, PO10
#   AF7, AF3, AF4, AF8, F5, F1, F2, F6
#   FT9, FT7, FC3, FC4, FT8, FT10, C5, C1
#   C2, C6, TP7, CP3, CPz, CP4, TP8, P5
#   P1, P2, P6, PO7, PO3, POz, PO4, PO8

# %%
# Загружаем данные для анализа
data = raw.get_data(picks=eeg_picks)
print(f"Данные для анализа микросостояний: {data.shape}")

# Извлекаем пики GFP
from pycrostates.preprocessing import extract_gfp_peaks
gfp_peaks = extract_gfp_peaks(data)
print(f"Пики GFP: {gfp_peaks.shape}")

# Кластеризация с разным количеством кластеров для сравнения
from pycrostates.clustering import KMeans
import numpy as np

# Попробуем разное количество кластеров
cluster_range = [3, 4, 5, 6]
models = {}

for n_clusters in cluster_range:
    print(f"\nКластеризация с {n_clusters} кластерами...")
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(gfp_peaks, n_jobs=1)
    models[n_clusters] = kmeans
    
    # Визуализируем карты микросостояний
    fig = kmeans.plot()
    plt.suptitle(f'Карты микросостояний - {n_clusters} кластеров')
    plt.show()
# Out:
# Данные для анализа микросостояний: (64, 193000)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 6
#       3 print(f"Данные для анализа микросостояний: {data.shape}")
#       5 # Извлекаем пики GFP
# ----> 6 from pycrostates.preprocessing import extract_gfp_peaks
#       7 gfp_peaks = extract_gfp_peaks(data)
#       8 print(f"Пики GFP: {gfp_peaks.shape}")
#
# ModuleNotFoundError: No module named 'pycrostates'
